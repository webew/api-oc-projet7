# %%
import requests

BASE_URL = "http://127.0.0.1:8000"

r = requests.get(f"{BASE_URL}/health", timeout=10)
print("status_code:", r.status_code)
print("json:", r.json())
# Out:
# status_code: 200
# json: {'status': 'ok'}

# %%
import requests

BASE_URL = "http://127.0.0.1:8000"

payload = {
    "features": {
        # Mets ici des features réelles attendues par ton modèle
        # Exemple fictif :
        "EXT_SOURCE_1": 0.5,
        "EXT_SOURCE_2": 0.7,
        "EXT_SOURCE_3": 0.2
    }
}

r = requests.post(f"{BASE_URL}/v1/predict", json=payload, timeout=30)
print("status_code:", r.status_code)
print("json:", r.json())
# Out:
# status_code: 200
# json: {'approved': False, 'probability_default': 0.09050889041337443}
